# %% [markdown]
# # The Battle of Neighborhoods - Week 2

# %% [markdown]
# ## Introduction/Business Problem

# %% [markdown]
# Buenos Aires is the biggest city of Argentina. The entire urban conglomerate has 17 million people, the Capital District is its main part and has 3 milloon people.
#
# The Capital is a tourist pole with 5.5 millio visitors every year. Buenos Aires has a wide variety of attractions, services and places. It has 50 neighborhoods, everyone is different, but ¿can we group them by similarity?
# Of course, yes. How homogeneous is the city? Where can we find those neighborhoods especially different from the rest?
#
# We want to detect the differences between some naighborhood clusters to help local business to exploit the cultural advantages of your neighborhood, and suggest to tourists where to look for new experiences in the city.

# %% [markdown]
# ## Data

# %% [markdown]
# We will use a CSV file that contains everyone of the 50 Buenos Aires' neighbourhoods and their respective Latitude and Lingitude. Then we will combine it with Foursquare information to be able of compare the different neighbourhoods.
# We are interested in the venues more common in every neighborhood. These will allow us to create 5 clusters.

# %% [markdown]
# ## Methodology

# %% [markdown]
# Our objective is to compare the 50 Buenos Aires' neighbourhoods and establish 5 different clusters that can describe the city based on its venues.
#
# To reach this objective we will use both Kmeans clustering and Hierarchical clustering. In order to do that, we have to pre-process the data and combine our original "barrios" dataset with the venue information provided by Foursquare. We will display the Buenos Aires' map with the neighborhood clusters.

# %% [markdown]
# ## Notebook

# %% [markdown]
# ### import some libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %% [markdown]
# ### create neighborhoods (barrios) dataset

# %%
barrios=pd.read_csv("buenosaires.csv") # import a csv file that contains every Buenos Aires's neighborhood and its coordinates

# %%
barrios.sample(7) # lets see 7 random neighborhoods
# Out:
#           Barrio   Latitud  Longitud
# 4   Barrio-Norte -34.58333 -58.40000
# 28      Paternal -34.60000 -58.46667
# 2      Balvanera -34.61018 -58.40654
# 6           Boca -34.63333 -58.35000
# 22         Nunez -34.55000 -58.45000
# 33      Saavedra -34.55000 -58.46667
# 42  Villa-Lugano -34.68333 -58.46667

# %% [markdown]
# ### Buenos Aires' neighborhood map

# %%
geo = Nominatim(user_agent="tor_explorer")
buenos_aires = geo.geocode("Buenos Aires, AR")
ba_mapa = folium.Map(location=[buenos_aires.latitude, buenos_aires.longitude], zoom_start=12)
for lat, long, label in zip(barrios['Latitud'], barrios['Longitud'], barrios['Barrio']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker([lat, long], radius=8, popup=label, color='red', fill=True, fill_color='#cc5531', fill_opacity=0.8, parse_html=False).add_to(ba_mapa)
ba_mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ### exploring Palermo

# %% [markdown]
# "Palermo" is the name of a Buenos Aires' neigborhood. We are exploring it, not the italian city that has the same name.

# %%
CLIENT_ID = 'NZIDRXI4IRRB3DII2ASPTGF0HV1WSO0GU2OA3LTOOGS2DZF4'
CLIENT_SECRET = 'DUCGZICGYFKAGH3125SZELPDAFYQLN1THHTAXJ5R4ODG4XC1'
VERSION = '20180605'
LIMIT = 100
radius = 500 

neighborhood_latitude = barrios.loc[24, 'Latitud'] 
neighborhood_longitude = barrios.loc[24, 'Longitud'] 
neighborhood_name = barrios.loc[24, 'Barrio'] 

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Palermo are -34.58333, -58.41667.

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=NZIDRXI4IRRB3DII2ASPTGF0HV1WSO0GU2OA3LTOOGS2DZF4&client_secret=DUCGZICGYFKAGH3125SZELPDAFYQLN1THHTAXJ5R4ODG4XC1&v=20180605&ll=-34.58333,-58.41667&radius=500&limit=100'

# %%
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues)
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
# lets see some Palermo's venues
nearby_venues.head()
# Out:
# <ipython-input-132-a4f4bbed81e4>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues)
#                            name                 categories        lat  \
# 0  Jardín Botánico Carlos Thays           Botanical Garden -34.582804
# 1                     Al Rawshe  Middle Eastern Restaurant -34.583899
# 2                   Museo Evita             History Museum -34.580689
# 3                        Suevia                     Bakery -34.582602
# 4  Museo Evita Restaurant & Bar     Argentinian Restaurant -34.580502
#
#          lng
# 0 -58.418427
# 1 -58.417907
# 2 -58.414731
# 3 -58.419802
# 4 -58.414846

# %% [markdown]
# ### create a sistem to search venues in every neighborhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Barrio', 
                  'Barrio Latitud', 
                  'Barrio Longitud', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
ba_venues = getNearbyVenues(names=barrios['Barrio'],
                                   latitudes=barrios['Latitud'],
                                   longitudes=barrios['Longitud']
                                  )
# Out:
# Agronomia
# Almagro
# Balvanera
# Barracas
# Barrio-Norte
# Belgrano
# Boca
# Boedo
# Caballito
# Centro
# Chacarita
# Coghlan
# Colegiales
# Congreso
# Constitucion
# Flores
# Floresta
# Liniers
# Mataderos
# Monte-Castro
# Montserrat
# Nueva-Pompeya
# Nunez
# Once
# Palermo
# Parque-Chacabuco
# Parque-Chas
# Parque-Patricios
# Paternal
# Puerto-Madero
# Pueyrredon
# Recoleta
# Retiro
# Saavedra
# San-Cristobal
# San-Telmo
# Velez-Sarsfield
# Versailles
# Villa-Crespo
# Villa-del-Parque
# Villa-Devoto
# Villa-General-Mitre
# Villa-Lugano
# Villa-Luro
# Villa-Ortuzar
# Villa-Real
# Villa-Riachuelo
# Villa-Santa-Rita
# Villa-Soldati
# Villa-Urquiza

# %%
# lets see some random venues
ba_venues.sample(10)
# Out:
#             Barrio  Barrio Latitud  Barrio Longitud                    Venue  \
# 580     Montserrat       -34.61667        -58.38333  Radio Cultura - FM 97.9
# 326      Chacarita       -34.58333        -58.45000                Garbarino
# 505       Floresta       -34.63333        -58.48333                Farmacity
# 80        Barracas       -34.65000        -58.36667                    Dylan
# 845       Recoleta       -34.58333        -58.40000    Plaza Bartolomé Mitre
# 1003  Villa-Crespo       -34.60000        -58.45000                 Tio Pupa
# 967      San-Telmo       -34.61667        -58.36667                  Shokudo
# 934       Saavedra       -34.55000        -58.46667       Boutique de Pizzas
# 868       Recoleta       -34.58333        -58.40000          Plaza Eva Perón
# 302      Chacarita       -34.58333        -58.45000                Megaphoto
#
#       Venue Latitude  Venue Longitude       Venue Category
# 580       -34.619303       -58.380136        Radio Station
# ...

# %%
# one hot encoding
ba_onehot = pd.get_dummies(ba_venues[['Venue Category']], prefix="", prefix_sep="")

# add borough column back to dataframe
ba_onehot['Barrio'] = ba_venues['Barrio'] 

# move borough column to the first column
fixed_columns = [ba_onehot.columns[-1]] + list(ba_onehot.columns[:-1])
ba_onehot = ba_onehot[fixed_columns]

ba_grouped = ba_onehot.groupby('Barrio').mean().reset_index()
ba_grouped.sample(10)
# Out:
#              Barrio  Accessories Store  American Restaurant  Arcade  \
# 36  Velez-Sarsfield                0.0                  0.0     0.0
# 18        Mataderos                0.0                  0.0     0.0
# 39     Villa-Devoto                0.0                  0.0     0.0
# 14     Constitucion                0.0                  0.0     0.0
# 16         Floresta                0.0                  0.0     0.0
# 2         Balvanera                0.0                  0.0     0.0
# 17          Liniers                0.0                  0.0     0.0
# 37       Versailles                0.0                  0.0     0.0
# 45  Villa-Riachuelo                0.0                  0.0     0.0
# 4      Barrio-Norte                0.0                  0.0     0.0
#
#     Argentinian Restaurant  Art Gallery  Art Museum  Arts & Entertainment  \
# 36                0.000000          0.0    0.000000                   0.0
# ...

# %% [markdown]
# ### lets take 5 random neighbours, and see they most common venues

# %%
for i in ba_grouped['Barrio'].sample(5):
    print("----"+i+"----")
    temp = ba_grouped[ba_grouped['Barrio'] == i].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(3))
    print('\n')
# Out:
# ----Villa-Luro----
#           venue  freq
# 0      Bus Stop  0.17
# 1     BBQ Joint  0.17
# 2  Tennis Court  0.08
#
#
# ----Monte-Castro----
#                     venue  freq
# 0                   Plaza  0.25
# 1  Argentinian Restaurant  0.25
# 2                    Café  0.25
#
#
# ----Versailles----
#             venue  freq
# 0     Sports Club  0.25
# 1    Soccer Field  0.12
# 2  Soccer Stadium  0.12
#
#
# ----Velez-Sarsfield----
#            venue  freq
# 0  Deli / Bodega  0.13
# 1       Pharmacy  0.13
# 2           Café  0.13
#
#
# ----Villa-General-Mitre----
#                  venue  freq
# 0       Ice Cream Shop  0.17
# 1           Restaurant  0.17
# 2  Empanada Restaurant  0.17

# %% [markdown]
# ### claster the neughbourhoods with Kmeans

# %%
kclusters = 5
ba_cluster = ba_grouped.drop('Barrio', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=135).fit(ba_cluster)

kmeans.labels_[::]
# Out:
# array([2, 4, 4, 1, 4, 4, 3, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 0, 4, 4, 4, 2,
#        4, 4, 4, 4, 2, 4, 4, 4, 2, 4, 4, 4, 4, 4, 4, 0, 4, 4, 4, 4, 2, 4,
#        2, 4, 4, 0, 4, 2])

# %%
barrios=pd.read_csv("buenosaires.csv")
barrios.insert(1, 'Cluster Kmeans', kmeans.labels_)

# %%
barrios.sample(5)
# Out:
#           Barrio  Cluster Kmeans   Latitud  Longitud
# 22         Nunez               4 -34.55000 -58.45000
# 30    Pueyrredon               2 -34.58333 -58.50000
# 16      Floresta               4 -34.63333 -58.48333
# 37    Versailles               0 -34.63333 -58.51667
# 38  Villa-Crespo               4 -34.60000 -58.45000

# %%
map_clusters = folium.Map(location=[buenos_aires.latitude, buenos_aires.longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(barrios['Latitud'], barrios['Longitud'], barrios['Barrio'], barrios['Cluster Kmeans']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ### lets try with a hierarchical clustering

# %%
import scipy.cluster.hierarchy as sch

# %%
dendrograma = sch.dendrogram(sch.linkage(ba_cluster, method = 'ward'))

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = kclusters, 
                    affinity = 'euclidean', 
                    linkage = 'ward')

y_hc = hc.fit_predict(ba_cluster)
y_hc
# Out:
# array([0, 1, 1, 3, 1, 1, 2, 4, 1, 1, 1, 1, 1, 1, 1, 1, 1, 0, 4, 1, 1, 0,
#        1, 1, 1, 4, 4, 1, 1, 1, 4, 1, 1, 1, 1, 1, 1, 0, 1, 1, 4, 1, 4, 1,
#        0, 1, 1, 0, 4, 0], dtype=int64)

# %%
barrios.insert(1, 'Cluster Hierarchical', y_hc)

# %%
map_clusters_her = folium.Map(location=[buenos_aires.latitude, buenos_aires.longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(barrios['Latitud'], barrios['Longitud'], barrios['Barrio'], barrios['Cluster Hierarchical']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## Results

# %% [markdown]
# See the maps, dendogram and tables just above.

# %% [markdown]
# ## Discussion

# %% [markdown]
# We observe that, as we see, every neighborhood has quite a variety of different venues. The city in general is pretty homogeneous: East, center and nort zones has the same cluster (cluster 4 in K means). Both K-means and Hierarchical Clustering shows this phenomenon.
#
# Nor-west, west and south neighborhoods where classified in other clusters. That neighborhoods are essentially different from the central and coastal neighborhoods. Hierarchical clustering shows  that more robustly, especially in the south-eastern areas of the city.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The city of Buenos Aires is a well-equipped area in terms of entertainment, recreation and gastronomy.
# The neighborhoods of the downtown and coastal area are similar to each other. The more remote areas show greater variety, in terms of venues.
#
# The recommendation for tourists is to visit the most remote areas to live more variety of experiences.
# The recommendation for local businesses in the central area is to exploit the features that make them distinctive to bring a greater variety to the city.
